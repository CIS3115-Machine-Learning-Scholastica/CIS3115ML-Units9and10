# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import shutil
import random
import tqdm

# %%
train_data = pd.read_csv('./CIFAR10/trainLabels.csv')

# %%
train_data.head(5)
# Out:
#    id       label
# 0   1        frog
# 1   2       truck
# 2   3       truck
# 3   4        deer
# 4   5  automobile

# %%
train_cat_dir = "CIFAR10\\train_images_by_cat\\"
train_dir = "CIFAR10\\train\\"
validate_cat_dir = "CIFAR10\\validate_images_by_cat\\"    # validate images are training images that are used to test validation. We know their catagory
validate_dir = "CIFAR10\\train"                  # take validation images from same folder as training images

percentValidate = 10         # percernt ot images to copy into validation folder

if os.path.exists(train_cat_dir):
    print("Error: The training category folder should not exist yet, please delete ", train_cat_dir)
    exit()
if os.path.exists(validate_cat_dir):
    print("Error: The training category folder should not exist yet, please delete ", validate_cat_dir)
    exit()
    
# tqdm simply adds the progress bar
for index, row in tqdm.tqdm( train_data.iterrows() ):
    id = row['id']
    label = row['label']
    
    dest_image_dir = train_cat_dir + label + "\\"    
    # Randomly copy a percent of the image to the validation folder
    if (random.randint(0,100) < percentValidate): 
        dest_image_dir = validate_cat_dir + label + "\\"  
        
    filename = train_dir + str(id) + ".png"
    # create a folder for this landmark ID if needed
    if not os.path.exists(dest_image_dir):
        os.makedirs(dest_image_dir)
    # make sure file exists, then copy it
    if (os.path.isfile(filename)):
        shutil.copy(filename, dest_image_dir)
        
print("Copied ", index, " files ")
# Out:
# Error: The training category folder should not exist yet, please delete  CIFAR10\train_images_by_cat\
# Error: The training category folder should not exist yet, please delete  CIFAR10\validate_images_by_cat\
# 0it [00:00, ?it/s]
# 22it [00:00, 212.36it/s]
# 45it [00:00, 215.17it/s]
# 68it [00:00, 219.24it/s]
# 91it [00:00, 222.29it/s]
# 117it [00:00, 229.84it/s]
# 138it [00:00, 213.34it/s]
# 159it [00:00, 209.33it/s]
# 179it [00:00, 197.46it/s]
# 198it [00:00, 192.66it/s]
# 217it [00:01, 183.28it/s]
# 236it [00:01, 184.15it/s]
# 255it [00:01, 179.18it/s]
# 273it [00:01, 173.37it/s]
# 291it [00:01, 173.89it/s]
# 309it [00:01, 175.31it/s]
# 327it [00:01, 174.75it/s]
# 348it [00:01, 183.69it/s]
# 371it [00:01, 193.66it/s]
# 391it [00:02, 192.47it/s]
# 411it [00:02, 187.02it/s]
# 430it [00:02, 181.35it/s]
# 449it [00:02, 182.86it/s]
# 470it [00:02, 189.33it/s]
# 490it [00:02, 185.22it/s]
# 509it [00:02, 180.40it/s]
# 530it [00:02, 185.49it/s]
# 549it [00:02, 184.82it/s]
# 568it [00:02, 176.63it/s]
# 586it [00:03, 174.58it/s]
# 604it [00:03, 172.36it/s]
# 625it [00:03, 181.79it/s]
# 644it [00:03, 182.59it/s]
# 663it [00:03, 169.59it/s]
# 681it [00:03, 161.58it/s]
# 704it [00:03, 176.71it/s]
# 723it [00:03, 176.12it/s]
# 745it [00:03, 186.02it/s]
# 765it [00:04, 179.91it/s]
# 784it [00:04, 149.39it/s]
# 801it [00:04, 138.50it/s]
# 821it [00:04, 152.05it/s]
# 838it [00:04, 144.94it/s]
# 857it [00:04, 154.54it/s]
# 877it [00:04, 164.11it/s]
# 900it [00:04, 178.81it/s]
# 919it [00:05, 177.14it/s]
# 938it [00:05, 177.90it/s]
# 957it [00:05, 165.86it/s]
# 975it [00:05, 169.51it/s]
# 997it [00:05, 180.36it/s]
# 1016it [00:05, 175.22it/s]
# 1034it [00:05, 174.21it/s]
# 1052it [00:05, 175.02it/s]
# 1073it [00:05, 181.47it/s]
# 1092it [00:06, 177.96it/s]
# 1110it [00:06, 168.30it/s]
# 1128it [00:06, 169.01it/s]
# 1150it [00:06, 181.43it/s]
# 1170it [00:06, 184.22it/s]
# 1189it [00:06, 182.99it/s]
# 1208it [00:06, 179.43it/s]
# 1230it [00:06, 189.09it/s]
# 1250it [00:06, 182.41it/s]
# 1269it [00:07, 171.31it/s]
# 1291it [00:07, 181.35it/s]
# 1310it [00:07, 172.98it/s]
# 1329it [00:07, 177.31it/s]
# 1347it [00:07, 148.79it/s]
# 1365it [00:07, 155.04it/s]
# 1385it [00:07, 165.95it/s]
# 1405it [00:07, 174.55it/s]
# 1430it [00:07, 189.86it/s]
# 1450it [00:08, 187.71it/s]
# 1475it [00:08, 202.10it/s]
# 1496it [00:08, 186.90it/s]
# 1516it [00:08, 168.06it/s]
# 1534it [00:08, 166.01it/s]
# 1552it [00:08, 161.43it/s]
# 1576it [00:08, 178.72it/s]
# 1595it [00:08, 180.88it/s]
# 1614it [00:08, 180.02it/s]
# 1633it [00:09, 177.31it/s]
# 1652it [00:09, 172.34it/s]
# 1674it [00:09, 183.09it/s]
# 1693it [00:09, 179.16it/s]
# 1712it [00:09, 179.33it/s]
# 1731it [00:09, 172.13it/s]
# 1749it [00:09, 170.97it/s]
# 1769it [00:09, 176.98it/s]
# 1790it [00:09, 183.97it/s]
# 1814it [00:10, 197.75it/s]
# 1835it [00:10, 198.71it/s]
# 1856it [00:10, 186.57it/s]
# 1876it [00:10, 189.47it/s]
# 1896it [00:10, 187.49it/s]
# 1915it [00:10, 179.32it/s]
# 1941it [00:10, 197.41it/s]
# 1962it [00:10, 195.44it/s]
# 1983it [00:10, 194.10it/s]
# 2003it [00:11, 188.21it/s]
# 2023it [00:11, 182.33it/s]
# 2045it [00:11, 191.75it/s]
# 2065it [00:11, 177.85it/s]
# 2088it [00:11, 188.62it/s]
# 2108it [00:11, 191.38it/s]
# 2128it [00:11, 188.98it/s]
# 2148it [00:11, 185.39it/s]
# 2167it [00:11, 159.25it/s]
# 2191it [00:12, 175.29it/s]
# 2214it [00:12, 187.51it/s]
# 2234it [00:12, 183.36it/s]
# 2254it [00:12, 184.39it/s]
# 2273it [00:12, 185.08it/s]
# 2292it [00:12, 178.88it/s]
# 2312it [00:12, 182.60it/s]
# 2331it [00:12, 181.70it/s]
# 2350it [00:12, 167.27it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-e5d23c722aff> in <module>
#      29     # make sure file exists, then copy it
#      30     if (os.path.isfile(filename)):
# ---> 31         shutil.copy(filename, dest_image_dir)
#      32
#      33 print("Copied ", index, " files ")
#
# ~\AppData\Local\Continuum\anaconda3\lib\shutil.py in copy(src, dst, follow_symlinks)
#     243     if os.path.isdir(dst):
#     244         dst = os.path.join(dst, os.path.basename(src))
# --> 245     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     246     copymode(src, dst, follow_symlinks=follow_symlinks)
#     247     return dst
#
# ~\AppData\Local\Continuum\anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
# --> 122                 copyfileobj(fsrc, fdst)
#     123     return dst
#     124
#
# KeyboardInterrupt:
# Exception ignored in: <bound method tqdm.__del__ of 2350it [00:13, 167.27it/s]>
# Traceback (most recent call last):
#   File "C:\Users\tgibbons\AppData\Local\Continuum\anaconda3\lib\site-packages\tqdm\_tqdm.py", line 931, in __del__
#     self.close()
#   File "C:\Users\tgibbons\AppData\Local\Continuum\anaconda3\lib\site-packages\tqdm\_tqdm.py", line 1133, in close
#     self._decr_instances(self)
#   File "C:\Users\tgibbons\AppData\Local\Continuum\anaconda3\lib\site-packages\tqdm\_tqdm.py", line 496, in _decr_instances
#     cls.monitor.exit()
#   File "C:\Users\tgibbons\AppData\Local\Continuum\anaconda3\lib\site-packages\tqdm\_monitor.py", line 52, in exit
#     self.join()
#   File "C:\Users\tgibbons\AppData\Local\Continuum\anaconda3\lib\threading.py", line 1053, in join
#     raise RuntimeError("cannot join current thread")
# RuntimeError: cannot join current thread
